# %%
import pandas as pd
d = pd.read_csv('/content/sample_data/ODI.csv')
d.head()
# Out:
#    Unnamed: 0  Year  Innings  Runs  Balls  Outs   Avg    SR   HS  50  100  4s  \
# 0           0  2007        3    61     74     3  20.3  82.4   52   1    0   3
# 1           1  2008       28   532    733    21  25.3  72.6   70   3    0  44
# 2           2  2009        7   102    155     4  25.5  65.8   43   0    0   5
# 3           3  2010       14   504    586    13  38.8  86.0  114   1    2  34
# 4           4  2011       16   611    739    11  55.5  82.7   95   6    0  40
#
#    6s  Dot %
# 0   1   47.3
# 1   3   53.9
# 2   1   52.3
# 3   7   43.9
# 4   9   45.6

# %%
d.head(25)
# Out:
#     index   Year  Innings    Runs  Balls  Outs   Avg     SR   HS  50  100  \
# 0       0   2007        3    88.0     61     0     -  144.3   50   1    0
# 1       1   2008        1     8.0      8     1     8  100.0    8   0    0
# 2       2   2009        8     NaN    129     7  20.7  112.4   52   1    0
# 3       3   2010        3    94.0     69     2    47  136.2   79   1    0
# 4       4   2011        3    80.0     60     3  26.7  133.3   53   1    0
# 5       5   2012        9   116.0     89     5  23.2  130.3   55   1    0
# 6       6   2013        1     NaN      8     1   NaN  100.0    8   0    0
# 7       7   2014        6   200.0    162     5    40  123.5   62   2    0
# 8       8   2015        2   128.0     90     2    64  142.2  106   0    1
# 9       9   2016       18   497.0    378    17  29.2  131.5   83   4    0
# 10     10   2017        9   279.0    165     9    31  169.1  118   1    1
# 11     11   2018       18   590.0    400    16  36.9  147.5  111   3    2
# ...

# %%
d.columns
# Out:
# Index(['index', 'Year', 'Innings', 'Runs', 'Balls', 'Outs', 'Avg', 'SR', 'HS',
#        '50', '100', '4s', '6s', 'Dot %'],
#       dtype='object')

# %%
d.tail()
# Out:
#     Unnamed: 0   Year  Innings  Runs  Balls  Outs   Avg     SR   HS  50  100  \
# 11          11   2018       19  1030   1029    14  73.6  100.1  162   3    5
# 12          12   2019       27  1490   1657    26  57.3   89.9  159   6    7
# 13          13   2020        3   171    187     3  57.0   91.4  119   0    1
# 14          14   2021        3    90    104     3  30.0   86.5   37   0    0
# 15          15  Total      220  9205  10354   188  49.0   88.9  264  43   29
#
#      4s   6s  Dot %
# 11  104   39   52.4
# 12  146   36   53.0
# 13   16    6   54.5
# 14   15    0   56.7
# 15  834  244   52.1

# %%
d.describe()
# Out:
#            index     Innings         Runs        Balls      Outs          SR  \
# count  16.000000   16.000000    13.000000    16.000000  16.00000   16.000000
# mean    7.500000   12.750000   397.769231   257.625000  11.00000  133.906250
# std     4.760952   24.449949   759.190924   495.407559  21.23833   18.120393
# min     0.000000    1.000000     8.000000     8.000000   0.00000  100.000000
# 25%     3.750000    3.000000    91.000000    62.500000   2.00000  128.600000
# 50%     7.500000    5.000000   128.000000    91.500000   4.00000  137.350000
# 75%    11.250000   10.250000   279.000000   195.250000  10.25000  144.325000
# max    15.000000  102.000000  2860.000000  2061.000000  88.00000  169.100000
#
#                HS         50        100          4s         6s      Dot %
# count   16.000000  16.000000  16.000000   16.000000   16.00000  16.000000
# mean    69.812500   2.750000   0.500000   31.625000   16.62500  38.668750
# ...

# %%
print(d.isnull().sum())
# Out:
# Unnamed: 0    0
# Year          0
# Innings       0
# Runs          0
# Balls         0
# Outs          0
# Avg           0
# SR            0
# HS            0
# 50            0
# 100           0
# 4s            0
# 6s            0
# Dot %         0
# dtype: int64

# %%
d.Runs=d.Runs.fillna(0)
print(d.isnull().sum())
# Out:
# Unnamed: 0    0
# Year          0
# Innings       0
# Runs          0
# Balls         0
# Outs          0
# Avg           0
# SR            0
# HS            0
# 50            0
# 100           0
# 4s            0
# 6s            0
# Dot %         0
# dtype: int64

# %%
d.shape
# Out:
# (16, 14)

# %%
d.dtypes
# Out:
# index        int64
# Year        object
# Innings      int64
# Runs       float64
# Balls        int64
# Outs         int64
# Avg         object
# SR         float64
# HS           int64
# 50           int64
# 100          int64
# 4s           int64
# 6s           int64
# Dot %      float64
# dtype: object

# %%
d.Avg=d.Avg.fillna(0)
print(d.isnull().sum())
# Out:
# index      0
# Year       0
# Innings    0
# Runs       0
# Balls      0
# Outs       0
# Avg        0
# SR         0
# HS         0
# 50         0
# 100        0
# 4s         0
# 6s         0
# Dot %      0
# dtype: int64

# %%
d.head(15)
# Out:
#     index  Year  Innings   Runs  Balls  Outs   Avg     SR   HS  50  100  4s  \
# 0       0  2007        3   88.0     61     0     -  144.3   50   1    0   9
# 1       1  2008        1    8.0      8     1     8  100.0    8   0    0   1
# 2       2  2009        8    0.0    129     7  20.7  112.4   52   1    0  12
# 3       3  2010        3   94.0     69     2    47  136.2   79   1    0   6
# 4       4  2011        3   80.0     60     3  26.7  133.3   53   1    0   5
# 5       5  2012        9  116.0     89     5  23.2  130.3   55   1    0   9
# 6       6  2013        1    0.0      8     1     0  100.0    8   0    0   0
# 7       7  2014        6  200.0    162     5    40  123.5   62   2    0  19
# 8       8  2015        2  128.0     90     2    64  142.2  106   0    1  14
# 9       9  2016       18  497.0    378    17  29.2  131.5   83   4    0  45
# 10     10  2017        9  279.0    165     9    31  169.1  118   1    1  30
# ...
